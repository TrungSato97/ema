# %% [markdown]
# # Iterative EMA Training Pipeline (CIFAR-10)
#
# This notebook orchestrates the iterative training pipeline:
# - Download CIFAR-10, split into train/val/test and inject label noise (configurable).
# - Train ResNet-18 pre-trained on ImageNet for each iteration.
# - After each iteration, compute predictions on **entire** training set,
#   update EMA predictions (alpha configurable), and filter samples whose EMA argmax disagrees with `label_noisy`.
# - Enforce per-class minimum kept ratio by promoting top-confident removed samples.
# - Repeat for up to `max_iterations` or until early-stop across iterations.
#
# **Sections**
# 1. Setup & imports
# 2. Load configuration
# 3. Prepare CIFAR dataset (images + CSV)
# 4. EDA (class distribution, sample images)
# 5. Dataloaders & transforms
# 6. Iterative training loop (demo run small config)
# 7. Visualizations and summary
# 8. How to resume

# %% [markdown]
# ## 1. Setup & imports

# %%
import os
os.environ["CUBLAS_WORKSPACE_CONFIG"] = ":4096:8"

# %%
import sys
import os
from pathlib import Path  # Sử dụng Path để lấy parent dễ dàng và an toàn hơn

# Lấy đường dẫn thư mục parent của current working directory
parent_dir = Path(os.getcwd()).parent

# Thêm vào sys.path (dùng str() để chuyển thành string)
sys.path.insert(0, str(parent_dir))

# Kiểm tra để debug
print("Thư mục parent:", parent_dir)
print("Sys.path cập nhật:", sys.path)
# Out:
# Thư mục parent: /mnt/c/Users/truon/learning/ptit/research/trung/M_10_01_2025/code/project
# Sys.path cập nhật: ['/mnt/c/Users/truon/learning/ptit/research/trung/M_10_01_2025/code/project', '/home/trungsato/miniconda3/envs/self_ensembling/lib/python310.zip', '/home/trungsato/miniconda3/envs/self_ensembling/lib/python3.10', '/home/trungsato/miniconda3/envs/self_ensembling/lib/python3.10/lib-dynload', '', '/home/trungsato/.local/lib/python3.10/site-packages', '/home/trungsato/miniconda3/envs/self_ensembling/lib/python3.10/site-packages']

# %%
import pandas as pd
from pathlib import Path
import logging
from src.config import TrainConfig
from src.dataset_utils import prepare_cifar_data, make_data_loaders
from src.train_loop import train_iteration
from src.ema_utils import update_ema, save_preds_npz, load_preds_npz
from src.filter_utils import filter_by_ema
from src.io_utils import make_dirs, save_dataframe_csv, save_npz
from src.eda import plot_class_distribution, plot_confusion_matrix, plot_filter_ratios_over_iterations, plot_confidence_histogram

logging.basicConfig(level=logging.INFO)

# %%
# 2) Config
config = TrainConfig()
# # For a quick demo, override a few params (small epochs)
# config.max_iterations = 1
# config.max_epochs_per_iter = 1
# config.batch_size = 256
# config.lr = 0.01
config.alpha = 0.9
config.exp_name = f"cifar_iter_ema_alpha_{config.alpha}_ratio_noise_{config.noise_ratio}"
config.make_exp_dir()
print(config)
# Out:
# TrainConfig(alpha=0.9, noise_ratio=0.8, min_keep_ratio=0.1, exp_name='cifar_iter_ema_alpha_0.9_ratio_noise_0.8', seed=42, data_dir='data_0.8', output_dir='outputs', output_eda='eda_data', exp_dir='outputs/cifar_iter_ema_alpha_0.9_ratio_noise_0.8', img_size=224, split_train=0.9, split_val=0.1, batch_size=256, num_workers=4, max_iterations=10, max_epochs_per_iter=200, patience_epoch=5, patience_iter=2, save_every_n_epochs=5, optimizer='sgd', lr=0.001, weight_decay=0.0001, momentum=0.9, device='cuda', use_amp=True, resume=False, num_classes=10, verbose=True)

# %%
from src.seed_utils import set_global_seed
set_global_seed(config.seed, deterministic=True)

# %%
# 3) Prepare data (download, images, CSV)
paths = prepare_cifar_data(config, force_download=False)
print(paths)

# Prepare data (chỉ chạy 1 lần, hoặc khi muốn refresh)
import torchvision
if not Path(config.data_dir, "csvs/train.csv").exists():
    paths = prepare_cifar_data(config, force_download=False)
else:
    # Tạo instance CIFAR10 để lấy class names (không download data)
    cifar_dataset = torchvision.datasets.CIFAR10(
        root=config.data_dir, 
        train=True, 
        download=False  # Quan trọng: không download vì data đã có
    )
    
    paths = {
        "train_csv": str(Path(config.data_dir) / "csvs/train.csv"),
        "val_csv": str(Path(config.data_dir) / "csvs/val.csv"),
        "test_csv": str(Path(config.data_dir) / "csvs/test.csv"),
        "class_names": cifar_dataset.classes  # Lấy từ instance
    }

print(paths)
# Out:
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████| 170M/170M [00:13<00:00, 12.4MB/s]
# INFO:src.dataset_utils:Split sizes: train=45000, val=5000, test=10000
# INFO:src.dataset_utils:Injected noise: train 36000/45000 (80.00%), val 4000/5000 (80.00%)
# INFO:src.dataset_utils:Saved CSVs at data_0.8/csvs
# {'train_csv': 'data_0.8/csvs/train.csv', 'val_csv': 'data_0.8/csvs/val.csv', 'test_csv': 'data_0.8/csvs/test.csv', 'class_names': ['airplane', 'automobile', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck']}
# {'train_csv': 'data_0.8/csvs/train.csv', 'val_csv': 'data_0.8/csvs/val.csv', 'test_csv': 'data_0.8/csvs/test.csv', 'class_names': ['airplane', 'automobile', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck']}

# %%
# 4) Initial EDA (class distribution)
plot_class_distribution({'train_csv': paths['train_csv'], 'val_csv': paths['val_csv'], 'test_csv': paths['test_csv']},
                        save_path=f"{config.exp_dir}/initial_class_distribution.png")
print('Saved initial class distribution plot.')
# Out:
# INFO:src.eda:Saved class distribution plot to outputs/cifar_iter_ema_alpha_0.9_ratio_noise_0.8/initial_class_distribution.png
# Saved initial class distribution plot.

# %%
# 5) Build dataloaders

original_train_csv = paths['train_csv']
original_val_csv = paths['val_csv']
original_test_csv = paths['test_csv']

# Đọc dataframe gốc để giữ thông tin đầy đủ
original_train_df = pd.read_csv(original_train_csv)
original_total_samples = len(original_train_df)


# Tạo data loaders từ dữ liệu gốc
set_global_seed(config.seed, deterministic=True)
dls = make_data_loaders(original_train_csv, original_val_csv, original_test_csv, config)
train_loader = dls['train']
val_loader = dls['val']
test_loader = dls['test']
train_full_loader = dls['train_full']  # Giữ nguyên từ dữ liệu gốc

print(f"Original training data: {original_total_samples} samples")
print(f"Initial train_loader: {len(train_loader.dataset)} samples")
print(f"train_full_loader: {len(train_full_loader.dataset)} samples")
# Out:
# Original training data: 45000 samples
# Initial train_loader: 45000 samples
# train_full_loader: 45000 samples

# %%
# 6) Iterative training driver (demo)
z_ema_prev = None
best_overall_val_acc = -1.0
iter_no_improve = 0
summary_rows = []
summary_path = f"{config.exp_dir}/training_summary.csv"

set_global_seed(config.seed, deterministic=True)

for i in range(config.max_iterations):
    print('Starting iteration', i)
    
    # Ở iteration > 0, tạo train_loader mới từ dữ liệu đã lọc
    if i > 0:
        set_global_seed(config.seed, deterministic=True)
        # Đường dẫn đến file CSV đã lọc từ iteration trước
        filtered_train_csv = f"{config.exp_dir}/iteration_{i-1}/train_kept_{i-1}.csv"

        # Kiểm tra file tồn tại
        if not os.path.exists(filtered_train_csv):
            print(f"Warning: Filtered CSV not found at {filtered_train_csv}, using original data")
            filtered_train_csv = original_train_csv
    
        # Tạo data loaders mới với filtered train data, nhưng vẫn sử dụng val và test gốc
        dls_filtered = make_data_loaders(filtered_train_csv, original_val_csv, original_test_csv, config)
        train_loader = dls_filtered['train']
        # Vẫn sử dụng train_full_loader gốc cho việc dự đoán
        # Log số lượng samples trong train_loader mới
        current_samples = len(train_loader.dataset)
        print(f"Iteration {i} train_loader: {current_samples} samples")
        print(f"Reduction from original: {original_total_samples - current_samples} samples ({((original_total_samples - current_samples)/original_total_samples*100):.2f}% reduction)")
        
    set_global_seed(config.seed, deterministic=True)
    result = train_iteration(i, config, train_loader, val_loader, test_loader, train_full_loader, start_epoch=0)
    indices = result['z_hat_indices']
    z_hat = result['z_hat']
    
    # Cập nhật EMA
    if z_ema_prev is None:
        z_ema_prev = update_ema(None, z_hat, config.alpha)
    else:
        z_ema_prev = update_ema(z_ema_prev, z_hat, config.alpha)
        
    # Save preds npz
    npz_path = f"{config.exp_dir}/iteration_{i}/preds_npz/preds_iter_{i}.npz"
    save_npz(npz_path, indices=indices.astype('int32'), z_hat=z_hat.astype('float32'), z_ema=z_ema_prev.astype('float32'))
    
    # Apply filter
    import pandas as pd
    train_df = pd.read_csv(paths['train_csv'])
    updated_df, stats = filter_by_ema(indices, z_ema_prev, original_train_df, config.min_keep_ratio)


    # Tính toán số lượng samples được giữ và bị loại
    kept_samples = len(updated_df[updated_df['filter_flag'] == 'kept'])
    removed_samples = len(updated_df[updated_df['filter_flag'] == 'removed'])


    
    # Log chi tiết filtering
    print(f"\nFiltering results for iteration {i}:")
    print(f"  Total samples: {len(updated_df)}")
    print(f"  Kept samples: {kept_samples} ({kept_samples/len(updated_df)*100:.2f}%)")
    print(f"  Removed samples: {removed_samples} ({removed_samples/len(updated_df)*100:.2f}%)")
    
    # Kiểm tra consistency
    if kept_samples + removed_samples != len(updated_df):
        print(f"  WARNING: Inconsistent counts! kept + removed = {kept_samples + removed_samples}, total = {len(updated_df)}")
    


    
    # Lưu file preds với đầy đủ thông tin và filter_flag
    preds_csv_path = f"{config.exp_dir}/iteration_{i}/preds/preds_iter_{i}.csv"
    os.makedirs(os.path.dirname(preds_csv_path), exist_ok=True)
    updated_df.to_csv(preds_csv_path, index=False)

    # Tạo file training cho iteration tiếp theo (chỉ chứa các samples được giữ lại)
    train_kept_df = updated_df[updated_df['filter_flag'] == 'kept'].copy()
    train_kept_csv_path = f"{config.exp_dir}/iteration_{i}/train_kept_{i}.csv"
    os.makedirs(os.path.dirname(train_kept_csv_path), exist_ok=True)
    train_kept_df.to_csv(train_kept_csv_path, index=False)
    
    print('Iteration', i, 'stats overall kept ratio:', stats['_overall']['kept_ratio_total'])

    # Kiểm tra số lượng samples trong file training tiếp theo
    expected_next_samples = len(train_kept_df)
    print(f"  Samples available for next iteration: {expected_next_samples}")
    
    # Tạo summary row và lưu ngay lập tức
    summary_row = {
        'iteration': i,
        'kept_ratio': stats['_overall']['kept_ratio_total'],
        'val_acc': result['best_val_acc'],
        'test_acc': result['test_acc'],
        'samples_kept': kept_samples,
        'samples_removed': removed_samples,
        'samples_total': len(updated_df),
        'training_samples_used': len(train_loader.dataset) if i == 0 else len(pd.read_csv(f"{config.exp_dir}/iteration_{i-1}/train_kept_{i-1}.csv")) if i > 0 else original_total_samples
    }
    
    summary_rows.append(summary_row)

    # Lưu summary ngay sau mỗi iteration để tránh mất dữ liệu
    current_summary_df = pd.DataFrame(summary_rows)
    current_summary_df.to_csv(summary_path, index=False)
    print(f"Summary saved to {summary_path}")

    # Log tóm tắt iteration
    print(f"\nIteration {i} completed:")
    print(f"  Validation accuracy: {result['best_val_acc']:.4f}")
    print(f"  Test accuracy: {result['test_acc']:.4f}")
    print(f"  Kept ratio: {stats['_overall']['kept_ratio_total']:.4f}")
    
    
    # Compare early-stop across iterations
    if result['best_val_acc'] > best_overall_val_acc:
        best_overall_val_acc = result['best_val_acc']
        iter_no_improve = 0
    else:
        iter_no_improve += 1
        if iter_no_improve > config.patience_iter:
            print('Stopping iterations due to no improvement across iterations.')
            break

            
print(f"\nTraining completed. Final summary saved to {summary_path}")
print(f"Best overall validation accuracy: {best_overall_val_acc:.4f}")
# Out:
# Starting iteration 0
# INFO:src.model_utils:Loaded ResNet18 with 10 output classes on device cuda
# /mnt/c/Users/truon/learning/ptit/research/trung/M_10_01_2025/code/project/src/train_loop.py:34: FutureWarning: `torch.cuda.amp.GradScaler(args...)` is deprecated. Please use `torch.amp.GradScaler('cuda', args...)` instead.
#   scaler = torch.cuda.amp.GradScaler() if use_amp and device.startswith("cuda") else None
# Train:   0%|                                                                                                              | 0/176 [00:00<?, ?it/s]/mnt/c/Users/truon/learning/ptit/research/trung/M_10_01_2025/code/project/src/train_loop.py:42: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast():
# INFO:src.train_loop:Iter 0 Epoch 0: train_acc=0.1060 val_acc=0.1200
# INFO:src.io_utils:Saved checkpoint outputs/cifar_iter_ema_alpha_0.9_ratio_noise_0.8/iteration_0/checkpoints/model_iter0_best.pth
# INFO:src.train_loop:Iter 0 Epoch 1: train_acc=0.1183 val_acc=0.1164
# INFO:src.train_loop:Iter 0 Epoch 2: train_acc=0.1256 val_acc=0.1264
# INFO:src.io_utils:Saved checkpoint outputs/cifar_iter_ema_alpha_0.9_ratio_noise_0.8/iteration_0/checkpoints/model_iter0_best.pth
# INFO:src.train_loop:Iter 0 Epoch 3: train_acc=0.1318 val_acc=0.1348
# INFO:src.io_utils:Saved checkpoint outputs/cifar_iter_ema_alpha_0.9_ratio_noise_0.8/iteration_0/checkpoints/model_iter0_best.pth
# INFO:src.train_loop:Iter 0 Epoch 4: train_acc=0.1350 val_acc=0.1388
# INFO:src.io_utils:Saved checkpoint outputs/cifar_iter_ema_alpha_0.9_ratio_noise_0.8/iteration_0/checkpoints/model_iter0_epoch5.pth
# INFO:src.io_utils:Saved checkpoint outputs/cifar_iter_ema_alpha_0.9_ratio_noise_0.8/iteration_0/checkpoints/model_iter0_best.pth
# INFO:src.train_loop:Iter 0 Epoch 5: train_acc=0.1397 val_acc=0.1402
# INFO:src.io_utils:Saved checkpoint outputs/cifar_iter_ema_alpha_0.9_ratio_noise_0.8/iteration_0/checkpoints/model_iter0_best.pth
# INFO:src.train_loop:Iter 0 Epoch 6: train_acc=0.1394 val_acc=0.1464
# INFO:src.io_utils:Saved checkpoint outputs/cifar_iter_ema_alpha_0.9_ratio_noise_0.8/iteration_0/checkpoints/model_iter0_best.pth
# INFO:src.train_loop:Iter 0 Epoch 7: train_acc=0.1460 val_acc=0.1482
# INFO:src.io_utils:Saved checkpoint outputs/cifar_iter_ema_alpha_0.9_ratio_noise_0.8/iteration_0/checkpoints/model_iter0_best.pth
# INFO:src.train_loop:Iter 0 Epoch 8: train_acc=0.1482 val_acc=0.1514
# INFO:src.io_utils:Saved checkpoint outputs/cifar_iter_ema_alpha_0.9_ratio_noise_0.8/iteration_0/checkpoints/model_iter0_best.pth
# INFO:src.train_loop:Iter 0 Epoch 9: train_acc=0.1483 val_acc=0.1510
# INFO:src.io_utils:Saved checkpoint outputs/cifar_iter_ema_alpha_0.9_ratio_noise_0.8/iteration_0/checkpoints/model_iter0_epoch10.pth
# INFO:src.train_loop:Iter 0 Epoch 10: train_acc=0.1493 val_acc=0.1524
# INFO:src.io_utils:Saved checkpoint outputs/cifar_iter_ema_alpha_0.9_ratio_noise_0.8/iteration_0/checkpoints/model_iter0_best.pth
# INFO:src.train_loop:Iter 0 Epoch 11: train_acc=0.1520 val_acc=0.1568
# INFO:src.io_utils:Saved checkpoint outputs/cifar_iter_ema_alpha_0.9_ratio_noise_0.8/iteration_0/checkpoints/model_iter0_best.pth
# INFO:src.train_loop:Iter 0 Epoch 12: train_acc=0.1533 val_acc=0.1538
# INFO:src.train_loop:Iter 0 Epoch 13: train_acc=0.1554 val_acc=0.1526
# INFO:src.train_loop:Iter 0 Epoch 14: train_acc=0.1584 val_acc=0.1546
# INFO:src.io_utils:Saved checkpoint outputs/cifar_iter_ema_alpha_0.9_ratio_noise_0.8/iteration_0/checkpoints/model_iter0_epoch15.pth
# INFO:src.train_loop:Iter 0 Epoch 15: train_acc=0.1569 val_acc=0.1552
# INFO:src.train_loop:Iter 0 Epoch 16: train_acc=0.1615 val_acc=0.1562
# INFO:src.train_loop:Early stopping in iteration 0 at epoch 16
# INFO:src.io_utils:Saved checkpoint outputs/cifar_iter_ema_alpha_0.9_ratio_noise_0.8/iteration_0/checkpoints/model_iter0_last.pth
# INFO:src.io_utils:Saved CSV to outputs/cifar_iter_ema_alpha_0.9_ratio_noise_0.8/iteration_0/metrics/metrics_epoch.csv
# INFO:src.model_utils:Loaded ResNet18 with 10 output classes on device cuda
# INFO:src.train_loop:Iteration 0 done. best_val_acc=0.1568 test_acc=0.5342
# INFO:src.ema_utils:Initializing EMA with z_hat
# INFO:src.io_utils:Saved npz to outputs/cifar_iter_ema_alpha_0.9_ratio_noise_0.8/iteration_0/preds_npz/preds_iter_0.npz
# Filtering results for iteration 0:
#   Total samples: 45000
#   Kept samples: 7831 (17.40%)
#   Removed samples: 37169 (82.60%)
# Iteration 0 stats overall kept ratio: 0.17402222222222222
#   Samples available for next iteration: 7831
# Summary saved to outputs/cifar_iter_ema_alpha_0.9_ratio_noise_0.8/training_summary.csv
#
# Iteration 0 completed:
#   Validation accuracy: 0.1568
#   Test accuracy: 0.5342
#   Kept ratio: 0.1740
# Starting iteration 1
# Iteration 1 train_loader: 7831 samples
# Reduction from original: 37169 samples (82.60% reduction)
# INFO:src.model_utils:Loaded ResNet18 with 10 output classes on device cuda
# /mnt/c/Users/truon/learning/ptit/research/trung/M_10_01_2025/code/project/src/train_loop.py:34: FutureWarning: `torch.cuda.amp.GradScaler(args...)` is deprecated. Please use `torch.amp.GradScaler('cuda', args...)` instead.
#   scaler = torch.cuda.amp.GradScaler() if use_amp and device.startswith("cuda") else None
# Train:   0%|                                                                                                               | 0/31 [00:00<?, ?it/s]/mnt/c/Users/truon/learning/ptit/research/trung/M_10_01_2025/code/project/src/train_loop.py:42: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast():
# INFO:src.train_loop:Iter 1 Epoch 0: train_acc=0.2270 val_acc=0.1310
# INFO:src.io_utils:Saved checkpoint outputs/cifar_iter_ema_alpha_0.9_ratio_noise_0.8/iteration_1/checkpoints/model_iter1_best.pth
# INFO:src.train_loop:Iter 1 Epoch 1: train_acc=0.4003 val_acc=0.1450
# INFO:src.io_utils:Saved checkpoint outputs/cifar_iter_ema_alpha_0.9_ratio_noise_0.8/iteration_1/checkpoints/model_iter1_best.pth
# INFO:src.train_loop:Iter 1 Epoch 2: train_acc=0.4777 val_acc=0.1482
# INFO:src.io_utils:Saved checkpoint outputs/cifar_iter_ema_alpha_0.9_ratio_noise_0.8/iteration_1/checkpoints/model_iter1_best.pth
# INFO:src.train_loop:Iter 1 Epoch 3: train_acc=0.5288 val_acc=0.1586
# INFO:src.io_utils:Saved checkpoint outputs/cifar_iter_ema_alpha_0.9_ratio_noise_0.8/iteration_1/checkpoints/model_iter1_best.pth
# INFO:src.train_loop:Iter 1 Epoch 4: train_acc=0.5594 val_acc=0.1620
# INFO:src.io_utils:Saved checkpoint outputs/cifar_iter_ema_alpha_0.9_ratio_noise_0.8/iteration_1/checkpoints/model_iter1_epoch5.pth
# INFO:src.io_utils:Saved checkpoint outputs/cifar_iter_ema_alpha_0.9_ratio_noise_0.8/iteration_1/checkpoints/model_iter1_best.pth
# INFO:src.train_loop:Iter 1 Epoch 5: train_acc=0.5726 val_acc=0.1634
# INFO:src.io_utils:Saved checkpoint outputs/cifar_iter_ema_alpha_0.9_ratio_noise_0.8/iteration_1/checkpoints/model_iter1_best.pth
# INFO:src.train_loop:Iter 1 Epoch 6: train_acc=0.5850 val_acc=0.1670
# INFO:src.io_utils:Saved checkpoint outputs/cifar_iter_ema_alpha_0.9_ratio_noise_0.8/iteration_1/checkpoints/model_iter1_best.pth
# INFO:src.train_loop:Iter 1 Epoch 7: train_acc=0.5928 val_acc=0.1648
# INFO:src.train_loop:Iter 1 Epoch 8: train_acc=0.6034 val_acc=0.1654
# INFO:src.train_loop:Iter 1 Epoch 9: train_acc=0.6099 val_acc=0.1682
# INFO:src.io_utils:Saved checkpoint outputs/cifar_iter_ema_alpha_0.9_ratio_noise_0.8/iteration_1/checkpoints/model_iter1_epoch10.pth
# INFO:src.io_utils:Saved checkpoint outputs/cifar_iter_ema_alpha_0.9_ratio_noise_0.8/iteration_1/checkpoints/model_iter1_best.pth
# INFO:src.train_loop:Iter 1 Epoch 10: train_acc=0.6138 val_acc=0.1708
# INFO:src.io_utils:Saved checkpoint outputs/cifar_iter_ema_alpha_0.9_ratio_noise_0.8/iteration_1/checkpoints/model_iter1_best.pth
# INFO:src.train_loop:Iter 1 Epoch 11: train_acc=0.6187 val_acc=0.1676
# INFO:src.train_loop:Iter 1 Epoch 12: train_acc=0.6253 val_acc=0.1708
# INFO:src.train_loop:Iter 1 Epoch 13: train_acc=0.6299 val_acc=0.1702
# INFO:src.train_loop:Iter 1 Epoch 14: train_acc=0.6385 val_acc=0.1704
# INFO:src.io_utils:Saved checkpoint outputs/cifar_iter_ema_alpha_0.9_ratio_noise_0.8/iteration_1/checkpoints/model_iter1_epoch15.pth
# INFO:src.train_loop:Iter 1 Epoch 15: train_acc=0.6380 val_acc=0.1702
# INFO:src.train_loop:Early stopping in iteration 1 at epoch 15
# INFO:src.io_utils:Saved checkpoint outputs/cifar_iter_ema_alpha_0.9_ratio_noise_0.8/iteration_1/checkpoints/model_iter1_last.pth
# INFO:src.io_utils:Saved CSV to outputs/cifar_iter_ema_alpha_0.9_ratio_noise_0.8/iteration_1/metrics/metrics_epoch.csv
# INFO:src.model_utils:Loaded ResNet18 with 10 output classes on device cuda
# INFO:src.train_loop:Iteration 1 done. best_val_acc=0.1708 test_acc=0.7051
# INFO:src.io_utils:Saved npz to outputs/cifar_iter_ema_alpha_0.9_ratio_noise_0.8/iteration_1/preds_npz/preds_iter_1.npz
# Filtering results for iteration 1:
#   Total samples: 45000
#   Kept samples: 8076 (17.95%)
#   Removed samples: 36924 (82.05%)
# Iteration 1 stats overall kept ratio: 0.17946666666666666
#   Samples available for next iteration: 8076
# Summary saved to outputs/cifar_iter_ema_alpha_0.9_ratio_noise_0.8/training_summary.csv
#
# Iteration 1 completed:
#   Validation accuracy: 0.1708
#   Test accuracy: 0.7051
#   Kept ratio: 0.1795
# Starting iteration 2
# Iteration 2 train_loader: 8076 samples
# Reduction from original: 36924 samples (82.05% reduction)
# INFO:src.model_utils:Loaded ResNet18 with 10 output classes on device cuda
# /mnt/c/Users/truon/learning/ptit/research/trung/M_10_01_2025/code/project/src/train_loop.py:34: FutureWarning: `torch.cuda.amp.GradScaler(args...)` is deprecated. Please use `torch.amp.GradScaler('cuda', args...)` instead.
#   scaler = torch.cuda.amp.GradScaler() if use_amp and device.startswith("cuda") else None
# Train:   0%|                                                                                                               | 0/32 [00:00<?, ?it/s]/mnt/c/Users/truon/learning/ptit/research/trung/M_10_01_2025/code/project/src/train_loop.py:42: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast():
# INFO:src.train_loop:Iter 2 Epoch 0: train_acc=0.2502 val_acc=0.1394
# INFO:src.io_utils:Saved checkpoint outputs/cifar_iter_ema_alpha_0.9_ratio_noise_0.8/iteration_2/checkpoints/model_iter2_best.pth
# INFO:src.train_loop:Iter 2 Epoch 1: train_acc=0.4699 val_acc=0.1508
# INFO:src.io_utils:Saved checkpoint outputs/cifar_iter_ema_alpha_0.9_ratio_noise_0.8/iteration_2/checkpoints/model_iter2_best.pth
# INFO:src.train_loop:Iter 2 Epoch 2: train_acc=0.5624 val_acc=0.1598
# INFO:src.io_utils:Saved checkpoint outputs/cifar_iter_ema_alpha_0.9_ratio_noise_0.8/iteration_2/checkpoints/model_iter2_best.pth
# INFO:src.train_loop:Iter 2 Epoch 3: train_acc=0.6164 val_acc=0.1616
# INFO:src.io_utils:Saved checkpoint outputs/cifar_iter_ema_alpha_0.9_ratio_noise_0.8/iteration_2/checkpoints/model_iter2_best.pth
# INFO:src.train_loop:Iter 2 Epoch 4: train_acc=0.6534 val_acc=0.1666
# INFO:src.io_utils:Saved checkpoint outputs/cifar_iter_ema_alpha_0.9_ratio_noise_0.8/iteration_2/checkpoints/model_iter2_epoch5.pth
# INFO:src.io_utils:Saved checkpoint outputs/cifar_iter_ema_alpha_0.9_ratio_noise_0.8/iteration_2/checkpoints/model_iter2_best.pth
# INFO:src.train_loop:Iter 2 Epoch 5: train_acc=0.6736 val_acc=0.1660
# INFO:src.train_loop:Iter 2 Epoch 6: train_acc=0.6927 val_acc=0.1700
# INFO:src.io_utils:Saved checkpoint outputs/cifar_iter_ema_alpha_0.9_ratio_noise_0.8/iteration_2/checkpoints/model_iter2_best.pth
# INFO:src.train_loop:Iter 2 Epoch 7: train_acc=0.6996 val_acc=0.1680
# INFO:src.train_loop:Iter 2 Epoch 8: train_acc=0.7161 val_acc=0.1712
# INFO:src.io_utils:Saved checkpoint outputs/cifar_iter_ema_alpha_0.9_ratio_noise_0.8/iteration_2/checkpoints/model_iter2_best.pth
# INFO:src.train_loop:Iter 2 Epoch 9: train_acc=0.7209 val_acc=0.1736
# INFO:src.io_utils:Saved checkpoint outputs/cifar_iter_ema_alpha_0.9_ratio_noise_0.8/iteration_2/checkpoints/model_iter2_epoch10.pth
# INFO:src.io_utils:Saved checkpoint outputs/cifar_iter_ema_alpha_0.9_ratio_noise_0.8/iteration_2/checkpoints/model_iter2_best.pth
# INFO:src.train_loop:Iter 2 Epoch 10: train_acc=0.7267 val_acc=0.1732
# INFO:src.train_loop:Iter 2 Epoch 11: train_acc=0.7337 val_acc=0.1706
# INFO:src.train_loop:Iter 2 Epoch 12: train_acc=0.7389 val_acc=0.1752
# INFO:src.io_utils:Saved checkpoint outputs/cifar_iter_ema_alpha_0.9_ratio_noise_0.8/iteration_2/checkpoints/model_iter2_best.pth
# INFO:src.train_loop:Iter 2 Epoch 13: train_acc=0.7443 val_acc=0.1732
# INFO:src.train_loop:Iter 2 Epoch 14: train_acc=0.7542 val_acc=0.1750
# INFO:src.io_utils:Saved checkpoint outputs/cifar_iter_ema_alpha_0.9_ratio_noise_0.8/iteration_2/checkpoints/model_iter2_epoch15.pth
# INFO:src.train_loop:Iter 2 Epoch 15: train_acc=0.7453 val_acc=0.1744
# INFO:src.train_loop:Iter 2 Epoch 16: train_acc=0.7619 val_acc=0.1740
# INFO:src.train_loop:Iter 2 Epoch 17: train_acc=0.7589 val_acc=0.1762
# INFO:src.io_utils:Saved checkpoint outputs/cifar_iter_ema_alpha_0.9_ratio_noise_0.8/iteration_2/checkpoints/model_iter2_best.pth
# INFO:src.train_loop:Iter 2 Epoch 18: train_acc=0.7642 val_acc=0.1730
# INFO:src.train_loop:Iter 2 Epoch 19: train_acc=0.7687 val_acc=0.1750
# INFO:src.io_utils:Saved checkpoint outputs/cifar_iter_ema_alpha_0.9_ratio_noise_0.8/iteration_2/checkpoints/model_iter2_epoch20.pth
# INFO:src.train_loop:Iter 2 Epoch 20: train_acc=0.7696 val_acc=0.1742
# INFO:src.train_loop:Iter 2 Epoch 21: train_acc=0.7713 val_acc=0.1730
# INFO:src.train_loop:Iter 2 Epoch 22: train_acc=0.7805 val_acc=0.1750
# INFO:src.train_loop:Early stopping in iteration 2 at epoch 22
# INFO:src.io_utils:Saved checkpoint outputs/cifar_iter_ema_alpha_0.9_ratio_noise_0.8/iteration_2/checkpoints/model_iter2_last.pth
# INFO:src.io_utils:Saved CSV to outputs/cifar_iter_ema_alpha_0.9_ratio_noise_0.8/iteration_2/metrics/metrics_epoch.csv
# INFO:src.model_utils:Loaded ResNet18 with 10 output classes on device cuda
# INFO:src.train_loop:Iteration 2 done. best_val_acc=0.1762 test_acc=0.7519
# INFO:src.io_utils:Saved npz to outputs/cifar_iter_ema_alpha_0.9_ratio_noise_0.8/iteration_2/preds_npz/preds_iter_2.npz
# Filtering results for iteration 2:
#   Total samples: 45000
#   Kept samples: 8180 (18.18%)
#   Removed samples: 36820 (81.82%)
# Iteration 2 stats overall kept ratio: 0.1817777777777778
#   Samples available for next iteration: 8180
# Summary saved to outputs/cifar_iter_ema_alpha_0.9_ratio_noise_0.8/training_summary.csv
#
# Iteration 2 completed:
#   Validation accuracy: 0.1762
#   Test accuracy: 0.7519
#   Kept ratio: 0.1818
# Starting iteration 3
# Iteration 3 train_loader: 8180 samples
# Reduction from original: 36820 samples (81.82% reduction)
# INFO:src.model_utils:Loaded ResNet18 with 10 output classes on device cuda
# /mnt/c/Users/truon/learning/ptit/research/trung/M_10_01_2025/code/project/src/train_loop.py:34: FutureWarning: `torch.cuda.amp.GradScaler(args...)` is deprecated. Please use `torch.amp.GradScaler('cuda', args...)` instead.
#   scaler = torch.cuda.amp.GradScaler() if use_amp and device.startswith("cuda") else None
# Train:   0%|                                                                                                               | 0/32 [00:00<?, ?it/s]/mnt/c/Users/truon/learning/ptit/research/trung/M_10_01_2025/code/project/src/train_loop.py:42: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast():
# INFO:src.train_loop:Iter 3 Epoch 0: train_acc=0.2515 val_acc=0.1342
# INFO:src.io_utils:Saved checkpoint outputs/cifar_iter_ema_alpha_0.9_ratio_noise_0.8/iteration_3/checkpoints/model_iter3_best.pth
# INFO:src.train_loop:Iter 3 Epoch 1: train_acc=0.4885 val_acc=0.1540
# INFO:src.io_utils:Saved checkpoint outputs/cifar_iter_ema_alpha_0.9_ratio_noise_0.8/iteration_3/checkpoints/model_iter3_best.pth
# INFO:src.train_loop:Iter 3 Epoch 2: train_acc=0.5881 val_acc=0.1612
# INFO:src.io_utils:Saved checkpoint outputs/cifar_iter_ema_alpha_0.9_ratio_noise_0.8/iteration_3/checkpoints/model_iter3_best.pth
# INFO:src.train_loop:Iter 3 Epoch 3: train_acc=0.6484 val_acc=0.1660
# INFO:src.io_utils:Saved checkpoint outputs/cifar_iter_ema_alpha_0.9_ratio_noise_0.8/iteration_3/checkpoints/model_iter3_best.pth
# INFO:src.train_loop:Iter 3 Epoch 4: train_acc=0.6886 val_acc=0.1644
# INFO:src.io_utils:Saved checkpoint outputs/cifar_iter_ema_alpha_0.9_ratio_noise_0.8/iteration_3/checkpoints/model_iter3_epoch5.pth
# INFO:src.train_loop:Iter 3 Epoch 5: train_acc=0.7020 val_acc=0.1714
# INFO:src.io_utils:Saved checkpoint outputs/cifar_iter_ema_alpha_0.9_ratio_noise_0.8/iteration_3/checkpoints/model_iter3_best.pth
# INFO:src.train_loop:Iter 3 Epoch 6: train_acc=0.7276 val_acc=0.1720
# INFO:src.io_utils:Saved checkpoint outputs/cifar_iter_ema_alpha_0.9_ratio_noise_0.8/iteration_3/checkpoints/model_iter3_best.pth
# INFO:src.train_loop:Iter 3 Epoch 7: train_acc=0.7380 val_acc=0.1744
# INFO:src.io_utils:Saved checkpoint outputs/cifar_iter_ema_alpha_0.9_ratio_noise_0.8/iteration_3/checkpoints/model_iter3_best.pth
# INFO:src.train_loop:Iter 3 Epoch 8: train_acc=0.7501 val_acc=0.1748
# INFO:src.io_utils:Saved checkpoint outputs/cifar_iter_ema_alpha_0.9_ratio_noise_0.8/iteration_3/checkpoints/model_iter3_best.pth
# INFO:src.train_loop:Iter 3 Epoch 9: train_acc=0.7634 val_acc=0.1732
# INFO:src.io_utils:Saved checkpoint outputs/cifar_iter_ema_alpha_0.9_ratio_noise_0.8/iteration_3/checkpoints/model_iter3_epoch10.pth
# INFO:src.train_loop:Iter 3 Epoch 10: train_acc=0.7702 val_acc=0.1750
# INFO:src.io_utils:Saved checkpoint outputs/cifar_iter_ema_alpha_0.9_ratio_noise_0.8/iteration_3/checkpoints/model_iter3_best.pth
# INFO:src.train_loop:Iter 3 Epoch 11: train_acc=0.7694 val_acc=0.1756
# INFO:src.io_utils:Saved checkpoint outputs/cifar_iter_ema_alpha_0.9_ratio_noise_0.8/iteration_3/checkpoints/model_iter3_best.pth
# INFO:src.train_loop:Iter 3 Epoch 12: train_acc=0.7748 val_acc=0.1734
# INFO:src.train_loop:Iter 3 Epoch 13: train_acc=0.7826 val_acc=0.1784
# INFO:src.io_utils:Saved checkpoint outputs/cifar_iter_ema_alpha_0.9_ratio_noise_0.8/iteration_3/checkpoints/model_iter3_best.pth
# INFO:src.train_loop:Iter 3 Epoch 14: train_acc=0.7798 val_acc=0.1754
# INFO:src.io_utils:Saved checkpoint outputs/cifar_iter_ema_alpha_0.9_ratio_noise_0.8/iteration_3/checkpoints/model_iter3_epoch15.pth
# INFO:src.train_loop:Iter 3 Epoch 15: train_acc=0.7850 val_acc=0.1772
# INFO:src.train_loop:Iter 3 Epoch 16: train_acc=0.7944 val_acc=0.1766
# INFO:src.train_loop:Iter 3 Epoch 17: train_acc=0.8044 val_acc=0.1778
# INFO:src.train_loop:Iter 3 Epoch 18: train_acc=0.8013 val_acc=0.1756
# INFO:src.train_loop:Early stopping in iteration 3 at epoch 18
# INFO:src.io_utils:Saved checkpoint outputs/cifar_iter_ema_alpha_0.9_ratio_noise_0.8/iteration_3/checkpoints/model_iter3_last.pth
# INFO:src.io_utils:Saved CSV to outputs/cifar_iter_ema_alpha_0.9_ratio_noise_0.8/iteration_3/metrics/metrics_epoch.csv
# INFO:src.model_utils:Loaded ResNet18 with 10 output classes on device cuda
# INFO:src.train_loop:Iteration 3 done. best_val_acc=0.1784 test_acc=0.7630
# INFO:src.io_utils:Saved npz to outputs/cifar_iter_ema_alpha_0.9_ratio_noise_0.8/iteration_3/preds_npz/preds_iter_3.npz
# Filtering results for iteration 3:
#   Total samples: 45000
#   Kept samples: 8194 (18.21%)
#   Removed samples: 36806 (81.79%)
# Iteration 3 stats overall kept ratio: 0.18208888888888888
#   Samples available for next iteration: 8194
# Summary saved to outputs/cifar_iter_ema_alpha_0.9_ratio_noise_0.8/training_summary.csv
#
# Iteration 3 completed:
#   Validation accuracy: 0.1784
#   Test accuracy: 0.7630
#   Kept ratio: 0.1821
# Starting iteration 4
# Iteration 4 train_loader: 8194 samples
# Reduction from original: 36806 samples (81.79% reduction)
# INFO:src.model_utils:Loaded ResNet18 with 10 output classes on device cuda
# /mnt/c/Users/truon/learning/ptit/research/trung/M_10_01_2025/code/project/src/train_loop.py:34: FutureWarning: `torch.cuda.amp.GradScaler(args...)` is deprecated. Please use `torch.amp.GradScaler('cuda', args...)` instead.
#   scaler = torch.cuda.amp.GradScaler() if use_amp and device.startswith("cuda") else None
# Train:   0%|                                                                                                               | 0/33 [00:00<?, ?it/s]/mnt/c/Users/truon/learning/ptit/research/trung/M_10_01_2025/code/project/src/train_loop.py:42: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast():
# INFO:src.train_loop:Iter 4 Epoch 0: train_acc=0.2465 val_acc=0.1348
# INFO:src.io_utils:Saved checkpoint outputs/cifar_iter_ema_alpha_0.9_ratio_noise_0.8/iteration_4/checkpoints/model_iter4_best.pth
# INFO:src.train_loop:Iter 4 Epoch 1: train_acc=0.4852 val_acc=0.1564
# INFO:src.io_utils:Saved checkpoint outputs/cifar_iter_ema_alpha_0.9_ratio_noise_0.8/iteration_4/checkpoints/model_iter4_best.pth
# INFO:src.train_loop:Iter 4 Epoch 2: train_acc=0.5869 val_acc=0.1624
# INFO:src.io_utils:Saved checkpoint outputs/cifar_iter_ema_alpha_0.9_ratio_noise_0.8/iteration_4/checkpoints/model_iter4_best.pth
# INFO:src.train_loop:Iter 4 Epoch 3: train_acc=0.6522 val_acc=0.1692
# INFO:src.io_utils:Saved checkpoint outputs/cifar_iter_ema_alpha_0.9_ratio_noise_0.8/iteration_4/checkpoints/model_iter4_best.pth
# INFO:src.train_loop:Iter 4 Epoch 4: train_acc=0.6936 val_acc=0.1688
# INFO:src.io_utils:Saved checkpoint outputs/cifar_iter_ema_alpha_0.9_ratio_noise_0.8/iteration_4/checkpoints/model_iter4_epoch5.pth
# INFO:src.train_loop:Iter 4 Epoch 5: train_acc=0.7089 val_acc=0.1710
# INFO:src.io_utils:Saved checkpoint outputs/cifar_iter_ema_alpha_0.9_ratio_noise_0.8/iteration_4/checkpoints/model_iter4_best.pth
# INFO:src.train_loop:Iter 4 Epoch 6: train_acc=0.7228 val_acc=0.1730
# INFO:src.io_utils:Saved checkpoint outputs/cifar_iter_ema_alpha_0.9_ratio_noise_0.8/iteration_4/checkpoints/model_iter4_best.pth
# INFO:src.train_loop:Iter 4 Epoch 7: train_acc=0.7392 val_acc=0.1760
# INFO:src.io_utils:Saved checkpoint outputs/cifar_iter_ema_alpha_0.9_ratio_noise_0.8/iteration_4/checkpoints/model_iter4_best.pth
# INFO:src.train_loop:Iter 4 Epoch 8: train_acc=0.7547 val_acc=0.1736
# INFO:src.train_loop:Iter 4 Epoch 9: train_acc=0.7637 val_acc=0.1732
# INFO:src.io_utils:Saved checkpoint outputs/cifar_iter_ema_alpha_0.9_ratio_noise_0.8/iteration_4/checkpoints/model_iter4_epoch10.pth
# INFO:src.train_loop:Iter 4 Epoch 10: train_acc=0.7610 val_acc=0.1788
# INFO:src.io_utils:Saved checkpoint outputs/cifar_iter_ema_alpha_0.9_ratio_noise_0.8/iteration_4/checkpoints/model_iter4_best.pth
# INFO:src.train_loop:Iter 4 Epoch 11: train_acc=0.7714 val_acc=0.1752
# INFO:src.train_loop:Iter 4 Epoch 12: train_acc=0.7791 val_acc=0.1790
# INFO:src.io_utils:Saved checkpoint outputs/cifar_iter_ema_alpha_0.9_ratio_noise_0.8/iteration_4/checkpoints/model_iter4_best.pth
# INFO:src.train_loop:Iter 4 Epoch 13: train_acc=0.7930 val_acc=0.1768
# INFO:src.train_loop:Iter 4 Epoch 14: train_acc=0.7886 val_acc=0.1800
# INFO:src.io_utils:Saved checkpoint outputs/cifar_iter_ema_alpha_0.9_ratio_noise_0.8/iteration_4/checkpoints/model_iter4_epoch15.pth
# INFO:src.io_utils:Saved checkpoint outputs/cifar_iter_ema_alpha_0.9_ratio_noise_0.8/iteration_4/checkpoints/model_iter4_best.pth
# INFO:src.train_loop:Iter 4 Epoch 15: train_acc=0.7903 val_acc=0.1764
# INFO:src.train_loop:Iter 4 Epoch 16: train_acc=0.7985 val_acc=0.1762
# INFO:src.train_loop:Iter 4 Epoch 17: train_acc=0.8111 val_acc=0.1756
# INFO:src.train_loop:Iter 4 Epoch 18: train_acc=0.8121 val_acc=0.1786
# INFO:src.train_loop:Iter 4 Epoch 19: train_acc=0.8157 val_acc=0.1760
# INFO:src.io_utils:Saved checkpoint outputs/cifar_iter_ema_alpha_0.9_ratio_noise_0.8/iteration_4/checkpoints/model_iter4_epoch20.pth
# INFO:src.train_loop:Early stopping in iteration 4 at epoch 19
# INFO:src.io_utils:Saved checkpoint outputs/cifar_iter_ema_alpha_0.9_ratio_noise_0.8/iteration_4/checkpoints/model_iter4_last.pth
# INFO:src.io_utils:Saved CSV to outputs/cifar_iter_ema_alpha_0.9_ratio_noise_0.8/iteration_4/metrics/metrics_epoch.csv
# INFO:src.model_utils:Loaded ResNet18 with 10 output classes on device cuda
# INFO:src.train_loop:Iteration 4 done. best_val_acc=0.1800 test_acc=0.7587
# INFO:src.io_utils:Saved npz to outputs/cifar_iter_ema_alpha_0.9_ratio_noise_0.8/iteration_4/preds_npz/preds_iter_4.npz
# Filtering results for iteration 4:
#   Total samples: 45000
#   Kept samples: 8214 (18.25%)
#   Removed samples: 36786 (81.75%)
# Iteration 4 stats overall kept ratio: 0.18253333333333333
#   Samples available for next iteration: 8214
# Summary saved to outputs/cifar_iter_ema_alpha_0.9_ratio_noise_0.8/training_summary.csv
#
# Iteration 4 completed:
#   Validation accuracy: 0.1800
#   Test accuracy: 0.7587
#   Kept ratio: 0.1825
# Starting iteration 5
# Iteration 5 train_loader: 8214 samples
# Reduction from original: 36786 samples (81.75% reduction)
# INFO:src.model_utils:Loaded ResNet18 with 10 output classes on device cuda
# /mnt/c/Users/truon/learning/ptit/research/trung/M_10_01_2025/code/project/src/train_loop.py:34: FutureWarning: `torch.cuda.amp.GradScaler(args...)` is deprecated. Please use `torch.amp.GradScaler('cuda', args...)` instead.
#   scaler = torch.cuda.amp.GradScaler() if use_amp and device.startswith("cuda") else None
# Train:   0%|                                                                                                               | 0/33 [00:00<?, ?it/s]/mnt/c/Users/truon/learning/ptit/research/trung/M_10_01_2025/code/project/src/train_loop.py:42: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast():
# INFO:src.train_loop:Iter 5 Epoch 0: train_acc=0.2558 val_acc=0.1396
# INFO:src.io_utils:Saved checkpoint outputs/cifar_iter_ema_alpha_0.9_ratio_noise_0.8/iteration_5/checkpoints/model_iter5_best.pth
# INFO:src.train_loop:Iter 5 Epoch 1: train_acc=0.4797 val_acc=0.1580
# INFO:src.io_utils:Saved checkpoint outputs/cifar_iter_ema_alpha_0.9_ratio_noise_0.8/iteration_5/checkpoints/model_iter5_best.pth
# INFO:src.train_loop:Iter 5 Epoch 2: train_acc=0.5860 val_acc=0.1646
# INFO:src.io_utils:Saved checkpoint outputs/cifar_iter_ema_alpha_0.9_ratio_noise_0.8/iteration_5/checkpoints/model_iter5_best.pth
# INFO:src.train_loop:Iter 5 Epoch 3: train_acc=0.6468 val_acc=0.1686
# INFO:src.io_utils:Saved checkpoint outputs/cifar_iter_ema_alpha_0.9_ratio_noise_0.8/iteration_5/checkpoints/model_iter5_best.pth
# INFO:src.train_loop:Iter 5 Epoch 4: train_acc=0.6908 val_acc=0.1678
# INFO:src.io_utils:Saved checkpoint outputs/cifar_iter_ema_alpha_0.9_ratio_noise_0.8/iteration_5/checkpoints/model_iter5_epoch5.pth
# INFO:src.train_loop:Iter 5 Epoch 5: train_acc=0.7168 val_acc=0.1726
# INFO:src.io_utils:Saved checkpoint outputs/cifar_iter_ema_alpha_0.9_ratio_noise_0.8/iteration_5/checkpoints/model_iter5_best.pth
# INFO:src.train_loop:Iter 5 Epoch 6: train_acc=0.7393 val_acc=0.1742
# INFO:src.io_utils:Saved checkpoint outputs/cifar_iter_ema_alpha_0.9_ratio_noise_0.8/iteration_5/checkpoints/model_iter5_best.pth
# INFO:src.train_loop:Iter 5 Epoch 7: train_acc=0.7484 val_acc=0.1716
# INFO:src.train_loop:Iter 5 Epoch 8: train_acc=0.7592 val_acc=0.1732
# INFO:src.train_loop:Iter 5 Epoch 9: train_acc=0.7691 val_acc=0.1744
# INFO:src.io_utils:Saved checkpoint outputs/cifar_iter_ema_alpha_0.9_ratio_noise_0.8/iteration_5/checkpoints/model_iter5_epoch10.pth
# INFO:src.io_utils:Saved checkpoint outputs/cifar_iter_ema_alpha_0.9_ratio_noise_0.8/iteration_5/checkpoints/model_iter5_best.pth
# INFO:src.train_loop:Iter 5 Epoch 10: train_acc=0.7816 val_acc=0.1754
# INFO:src.io_utils:Saved checkpoint outputs/cifar_iter_ema_alpha_0.9_ratio_noise_0.8/iteration_5/checkpoints/model_iter5_best.pth
# INFO:src.train_loop:Iter 5 Epoch 11: train_acc=0.7857 val_acc=0.1764
# INFO:src.io_utils:Saved checkpoint outputs/cifar_iter_ema_alpha_0.9_ratio_noise_0.8/iteration_5/checkpoints/model_iter5_best.pth
# INFO:src.train_loop:Iter 5 Epoch 12: train_acc=0.7966 val_acc=0.1762
# INFO:src.train_loop:Iter 5 Epoch 13: train_acc=0.8022 val_acc=0.1778
# INFO:src.io_utils:Saved checkpoint outputs/cifar_iter_ema_alpha_0.9_ratio_noise_0.8/iteration_5/checkpoints/model_iter5_best.pth
# INFO:src.train_loop:Iter 5 Epoch 14: train_acc=0.8050 val_acc=0.1766
# INFO:src.io_utils:Saved checkpoint outputs/cifar_iter_ema_alpha_0.9_ratio_noise_0.8/iteration_5/checkpoints/model_iter5_epoch15.pth
# INFO:src.train_loop:Iter 5 Epoch 15: train_acc=0.8025 val_acc=0.1760
# INFO:src.train_loop:Iter 5 Epoch 16: train_acc=0.8143 val_acc=0.1754
# INFO:src.train_loop:Iter 5 Epoch 17: train_acc=0.8123 val_acc=0.1774
# INFO:src.train_loop:Iter 5 Epoch 18: train_acc=0.8150 val_acc=0.1782
# INFO:src.io_utils:Saved checkpoint outputs/cifar_iter_ema_alpha_0.9_ratio_noise_0.8/iteration_5/checkpoints/model_iter5_best.pth
# INFO:src.train_loop:Iter 5 Epoch 19: train_acc=0.8219 val_acc=0.1774
# INFO:src.io_utils:Saved checkpoint outputs/cifar_iter_ema_alpha_0.9_ratio_noise_0.8/iteration_5/checkpoints/model_iter5_epoch20.pth
# INFO:src.train_loop:Iter 5 Epoch 20: train_acc=0.8142 val_acc=0.1798
# INFO:src.io_utils:Saved checkpoint outputs/cifar_iter_ema_alpha_0.9_ratio_noise_0.8/iteration_5/checkpoints/model_iter5_best.pth
# INFO:src.train_loop:Iter 5 Epoch 21: train_acc=0.8244 val_acc=0.1786
# INFO:src.train_loop:Iter 5 Epoch 22: train_acc=0.8251 val_acc=0.1798
# INFO:src.train_loop:Iter 5 Epoch 23: train_acc=0.8335 val_acc=0.1794
# INFO:src.train_loop:Iter 5 Epoch 24: train_acc=0.8293 val_acc=0.1778
# INFO:src.io_utils:Saved checkpoint outputs/cifar_iter_ema_alpha_0.9_ratio_noise_0.8/iteration_5/checkpoints/model_iter5_epoch25.pth
# INFO:src.train_loop:Iter 5 Epoch 25: train_acc=0.8335 val_acc=0.1790
# INFO:src.train_loop:Early stopping in iteration 5 at epoch 25
# INFO:src.io_utils:Saved checkpoint outputs/cifar_iter_ema_alpha_0.9_ratio_noise_0.8/iteration_5/checkpoints/model_iter5_last.pth
# INFO:src.io_utils:Saved CSV to outputs/cifar_iter_ema_alpha_0.9_ratio_noise_0.8/iteration_5/metrics/metrics_epoch.csv
# INFO:src.model_utils:Loaded ResNet18 with 10 output classes on device cuda
# INFO:src.train_loop:Iteration 5 done. best_val_acc=0.1798 test_acc=0.7829
# INFO:src.io_utils:Saved npz to outputs/cifar_iter_ema_alpha_0.9_ratio_noise_0.8/iteration_5/preds_npz/preds_iter_5.npz
# Filtering results for iteration 5:
#   Total samples: 45000
#   Kept samples: 8252 (18.34%)
#   Removed samples: 36748 (81.66%)
# Iteration 5 stats overall kept ratio: 0.18337777777777778
#   Samples available for next iteration: 8252
# Summary saved to outputs/cifar_iter_ema_alpha_0.9_ratio_noise_0.8/training_summary.csv
#
# Iteration 5 completed:
#   Validation accuracy: 0.1798
#   Test accuracy: 0.7829
#   Kept ratio: 0.1834
# Starting iteration 6
# Iteration 6 train_loader: 8252 samples
# Reduction from original: 36748 samples (81.66% reduction)
# INFO:src.model_utils:Loaded ResNet18 with 10 output classes on device cuda
# /mnt/c/Users/truon/learning/ptit/research/trung/M_10_01_2025/code/project/src/train_loop.py:34: FutureWarning: `torch.cuda.amp.GradScaler(args...)` is deprecated. Please use `torch.amp.GradScaler('cuda', args...)` instead.
#   scaler = torch.cuda.amp.GradScaler() if use_amp and device.startswith("cuda") else None
# Train:   0%|                                                                                                               | 0/33 [00:00<?, ?it/s]/mnt/c/Users/truon/learning/ptit/research/trung/M_10_01_2025/code/project/src/train_loop.py:42: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast():
# INFO:src.train_loop:Iter 6 Epoch 0: train_acc=0.2570 val_acc=0.1410
# INFO:src.io_utils:Saved checkpoint outputs/cifar_iter_ema_alpha_0.9_ratio_noise_0.8/iteration_6/checkpoints/model_iter6_best.pth
# INFO:src.train_loop:Iter 6 Epoch 1: train_acc=0.4873 val_acc=0.1536
# INFO:src.io_utils:Saved checkpoint outputs/cifar_iter_ema_alpha_0.9_ratio_noise_0.8/iteration_6/checkpoints/model_iter6_best.pth
# INFO:src.train_loop:Iter 6 Epoch 2: train_acc=0.5904 val_acc=0.1690
# INFO:src.io_utils:Saved checkpoint outputs/cifar_iter_ema_alpha_0.9_ratio_noise_0.8/iteration_6/checkpoints/model_iter6_best.pth
# INFO:src.train_loop:Iter 6 Epoch 3: train_acc=0.6554 val_acc=0.1700
# INFO:src.io_utils:Saved checkpoint outputs/cifar_iter_ema_alpha_0.9_ratio_noise_0.8/iteration_6/checkpoints/model_iter6_best.pth
# INFO:src.train_loop:Iter 6 Epoch 4: train_acc=0.6901 val_acc=0.1680
# INFO:src.io_utils:Saved checkpoint outputs/cifar_iter_ema_alpha_0.9_ratio_noise_0.8/iteration_6/checkpoints/model_iter6_epoch5.pth
# INFO:src.train_loop:Iter 6 Epoch 5: train_acc=0.7292 val_acc=0.1744
# INFO:src.io_utils:Saved checkpoint outputs/cifar_iter_ema_alpha_0.9_ratio_noise_0.8/iteration_6/checkpoints/model_iter6_best.pth
# INFO:src.train_loop:Iter 6 Epoch 6: train_acc=0.7419 val_acc=0.1730
# INFO:src.train_loop:Iter 6 Epoch 7: train_acc=0.7570 val_acc=0.1756
# INFO:src.io_utils:Saved checkpoint outputs/cifar_iter_ema_alpha_0.9_ratio_noise_0.8/iteration_6/checkpoints/model_iter6_best.pth
# INFO:src.train_loop:Iter 6 Epoch 8: train_acc=0.7723 val_acc=0.1744
# INFO:src.train_loop:Iter 6 Epoch 9: train_acc=0.7850 val_acc=0.1754
# INFO:src.io_utils:Saved checkpoint outputs/cifar_iter_ema_alpha_0.9_ratio_noise_0.8/iteration_6/checkpoints/model_iter6_epoch10.pth
# INFO:src.train_loop:Iter 6 Epoch 10: train_acc=0.7809 val_acc=0.1754
# INFO:src.train_loop:Iter 6 Epoch 11: train_acc=0.7984 val_acc=0.1766
# INFO:src.io_utils:Saved checkpoint outputs/cifar_iter_ema_alpha_0.9_ratio_noise_0.8/iteration_6/checkpoints/model_iter6_best.pth
# INFO:src.train_loop:Iter 6 Epoch 12: train_acc=0.7981 val_acc=0.1786
# INFO:src.io_utils:Saved checkpoint outputs/cifar_iter_ema_alpha_0.9_ratio_noise_0.8/iteration_6/checkpoints/model_iter6_best.pth
# INFO:src.train_loop:Iter 6 Epoch 13: train_acc=0.8108 val_acc=0.1790
# INFO:src.io_utils:Saved checkpoint outputs/cifar_iter_ema_alpha_0.9_ratio_noise_0.8/iteration_6/checkpoints/model_iter6_best.pth
# INFO:src.train_loop:Iter 6 Epoch 14: train_acc=0.8085 val_acc=0.1802
# INFO:src.io_utils:Saved checkpoint outputs/cifar_iter_ema_alpha_0.9_ratio_noise_0.8/iteration_6/checkpoints/model_iter6_epoch15.pth
# INFO:src.io_utils:Saved checkpoint outputs/cifar_iter_ema_alpha_0.9_ratio_noise_0.8/iteration_6/checkpoints/model_iter6_best.pth
# INFO:src.train_loop:Iter 6 Epoch 15: train_acc=0.8091 val_acc=0.1802
# INFO:src.train_loop:Iter 6 Epoch 16: train_acc=0.8170 val_acc=0.1776
# INFO:src.train_loop:Iter 6 Epoch 17: train_acc=0.8209 val_acc=0.1768
# INFO:src.train_loop:Iter 6 Epoch 18: train_acc=0.8180 val_acc=0.1772
# INFO:src.train_loop:Iter 6 Epoch 19: train_acc=0.8263 val_acc=0.1784
# INFO:src.io_utils:Saved checkpoint outputs/cifar_iter_ema_alpha_0.9_ratio_noise_0.8/iteration_6/checkpoints/model_iter6_epoch20.pth
# INFO:src.train_loop:Early stopping in iteration 6 at epoch 19
# INFO:src.io_utils:Saved checkpoint outputs/cifar_iter_ema_alpha_0.9_ratio_noise_0.8/iteration_6/checkpoints/model_iter6_last.pth
# INFO:src.io_utils:Saved CSV to outputs/cifar_iter_ema_alpha_0.9_ratio_noise_0.8/iteration_6/metrics/metrics_epoch.csv
# INFO:src.model_utils:Loaded ResNet18 with 10 output classes on device cuda
# INFO:src.train_loop:Iteration 6 done. best_val_acc=0.1802 test_acc=0.7862
# INFO:src.io_utils:Saved npz to outputs/cifar_iter_ema_alpha_0.9_ratio_noise_0.8/iteration_6/preds_npz/preds_iter_6.npz
# Filtering results for iteration 6:
#   Total samples: 45000
#   Kept samples: 8268 (18.37%)
#   Removed samples: 36732 (81.63%)
# Iteration 6 stats overall kept ratio: 0.18373333333333333
#   Samples available for next iteration: 8268
# Summary saved to outputs/cifar_iter_ema_alpha_0.9_ratio_noise_0.8/training_summary.csv
#
# Iteration 6 completed:
#   Validation accuracy: 0.1802
#   Test accuracy: 0.7862
#   Kept ratio: 0.1837
# Starting iteration 7
# Iteration 7 train_loader: 8268 samples
# Reduction from original: 36732 samples (81.63% reduction)
# INFO:src.model_utils:Loaded ResNet18 with 10 output classes on device cuda
# /mnt/c/Users/truon/learning/ptit/research/trung/M_10_01_2025/code/project/src/train_loop.py:34: FutureWarning: `torch.cuda.amp.GradScaler(args...)` is deprecated. Please use `torch.amp.GradScaler('cuda', args...)` instead.
#   scaler = torch.cuda.amp.GradScaler() if use_amp and device.startswith("cuda") else None
# ...
# INFO:src.io_utils:Saved checkpoint outputs/cifar_iter_ema_alpha_0.9_ratio_noise_0.8/iteration_7/checkpoints/model_iter7_best.pth
# INFO:src.train_loop:Iter 7 Epoch 4: train_acc=0.7066 val_acc=0.1728
# INFO:src.io_utils:Saved checkpoint outputs/cifar_iter_ema_alpha_0.9_ratio_noise_0.8/iteration_7/checkpoints/model_iter7_epoch5.pth
# INFO:src.io_utils:Saved checkpoint outputs/cifar_iter_ema_alpha_0.9_ratio_noise_0.8/iteration_7/checkpoints/model_iter7_best.pth
# INFO:src.train_loop:Iter 7 Epoch 5: train_acc=0.7171 val_acc=0.1714
# INFO:src.train_loop:Iter 7 Epoch 6: train_acc=0.7437 val_acc=0.1748
# INFO:src.io_utils:Saved checkpoint outputs/cifar_iter_ema_alpha_0.9_ratio_noise_0.8/iteration_7/checkpoints/model_iter7_best.pth
# INFO:src.train_loop:Iter 7 Epoch 7: train_acc=0.7623 val_acc=0.1786
# INFO:src.io_utils:Saved checkpoint outputs/cifar_iter_ema_alpha_0.9_ratio_noise_0.8/iteration_7/checkpoints/model_iter7_best.pth
# INFO:src.train_loop:Iter 7 Epoch 8: train_acc=0.7686 val_acc=0.1754
# INFO:src.train_loop:Iter 7 Epoch 9: train_acc=0.7816 val_acc=0.1770
# INFO:src.io_utils:Saved checkpoint outputs/cifar_iter_ema_alpha_0.9_ratio_noise_0.8/iteration_7/checkpoints/model_iter7_epoch10.pth
# INFO:src.train_loop:Iter 7 Epoch 10: train_acc=0.7880 val_acc=0.1772
# INFO:src.train_loop:Iter 7 Epoch 11: train_acc=0.7910 val_acc=0.1760
# INFO:src.train_loop:Iter 7 Epoch 12: train_acc=0.7978 val_acc=0.1772
# INFO:src.train_loop:Early stopping in iteration 7 at epoch 12
# INFO:src.io_utils:Saved checkpoint outputs/cifar_iter_ema_alpha_0.9_ratio_noise_0.8/iteration_7/checkpoints/model_iter7_last.pth
# INFO:src.io_utils:Saved CSV to outputs/cifar_iter_ema_alpha_0.9_ratio_noise_0.8/iteration_7/metrics/metrics_epoch.csv
# INFO:src.model_utils:Loaded ResNet18 with 10 output classes on device cuda
# INFO:src.train_loop:Iteration 7 done. best_val_acc=0.1786 test_acc=0.7582
# INFO:src.io_utils:Saved npz to outputs/cifar_iter_ema_alpha_0.9_ratio_noise_0.8/iteration_7/preds_npz/preds_iter_7.npz
# Filtering results for iteration 7:
#   Total samples: 45000
#   Kept samples: 8245 (18.32%)
#   Removed samples: 36755 (81.68%)
# Iteration 7 stats overall kept ratio: 0.18322222222222223
#   Samples available for next iteration: 8245
# Summary saved to outputs/cifar_iter_ema_alpha_0.9_ratio_noise_0.8/training_summary.csv
#
# Iteration 7 completed:
#   Validation accuracy: 0.1786
#   Test accuracy: 0.7582
#   Kept ratio: 0.1832
# Starting iteration 8
# Iteration 8 train_loader: 8245 samples
# Reduction from original: 36755 samples (81.68% reduction)
# INFO:src.model_utils:Loaded ResNet18 with 10 output classes on device cuda
# /mnt/c/Users/truon/learning/ptit/research/trung/M_10_01_2025/code/project/src/train_loop.py:34: FutureWarning: `torch.cuda.amp.GradScaler(args...)` is deprecated. Please use `torch.amp.GradScaler('cuda', args...)` instead.
#   scaler = torch.cuda.amp.GradScaler() if use_amp and device.startswith("cuda") else None
# Train:   0%|                                                                                                               | 0/33 [00:00<?, ?it/s]/mnt/c/Users/truon/learning/ptit/research/trung/M_10_01_2025/code/project/src/train_loop.py:42: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast():
# INFO:src.train_loop:Iter 8 Epoch 0: train_acc=0.2509 val_acc=0.1322
# INFO:src.io_utils:Saved checkpoint outputs/cifar_iter_ema_alpha_0.9_ratio_noise_0.8/iteration_8/checkpoints/model_iter8_best.pth
# INFO:src.train_loop:Iter 8 Epoch 1: train_acc=0.4873 val_acc=0.1528
# INFO:src.io_utils:Saved checkpoint outputs/cifar_iter_ema_alpha_0.9_ratio_noise_0.8/iteration_8/checkpoints/model_iter8_best.pth
# INFO:src.train_loop:Iter 8 Epoch 2: train_acc=0.5858 val_acc=0.1650
# INFO:src.io_utils:Saved checkpoint outputs/cifar_iter_ema_alpha_0.9_ratio_noise_0.8/iteration_8/checkpoints/model_iter8_best.pth
# INFO:src.train_loop:Iter 8 Epoch 3: train_acc=0.6598 val_acc=0.1700
# INFO:src.io_utils:Saved checkpoint outputs/cifar_iter_ema_alpha_0.9_ratio_noise_0.8/iteration_8/checkpoints/model_iter8_best.pth
# INFO:src.train_loop:Iter 8 Epoch 4: train_acc=0.7010 val_acc=0.1720
# INFO:src.io_utils:Saved checkpoint outputs/cifar_iter_ema_alpha_0.9_ratio_noise_0.8/iteration_8/checkpoints/model_iter8_epoch5.pth
# INFO:src.io_utils:Saved checkpoint outputs/cifar_iter_ema_alpha_0.9_ratio_noise_0.8/iteration_8/checkpoints/model_iter8_best.pth
# INFO:src.train_loop:Iter 8 Epoch 5: train_acc=0.7257 val_acc=0.1764
# INFO:src.io_utils:Saved checkpoint outputs/cifar_iter_ema_alpha_0.9_ratio_noise_0.8/iteration_8/checkpoints/model_iter8_best.pth
# INFO:src.train_loop:Iter 8 Epoch 6: train_acc=0.7497 val_acc=0.1758
# INFO:src.train_loop:Iter 8 Epoch 7: train_acc=0.7573 val_acc=0.1810
# INFO:src.io_utils:Saved checkpoint outputs/cifar_iter_ema_alpha_0.9_ratio_noise_0.8/iteration_8/checkpoints/model_iter8_best.pth
# INFO:src.train_loop:Iter 8 Epoch 8: train_acc=0.7756 val_acc=0.1776
# INFO:src.train_loop:Iter 8 Epoch 9: train_acc=0.7816 val_acc=0.1788
# INFO:src.io_utils:Saved checkpoint outputs/cifar_iter_ema_alpha_0.9_ratio_noise_0.8/iteration_8/checkpoints/model_iter8_epoch10.pth
# INFO:src.train_loop:Iter 8 Epoch 10: train_acc=0.7902 val_acc=0.1782
# INFO:src.train_loop:Iter 8 Epoch 11: train_acc=0.7992 val_acc=0.1766
# INFO:src.train_loop:Iter 8 Epoch 12: train_acc=0.7981 val_acc=0.1768
# INFO:src.train_loop:Early stopping in iteration 8 at epoch 12
# INFO:src.io_utils:Saved checkpoint outputs/cifar_iter_ema_alpha_0.9_ratio_noise_0.8/iteration_8/checkpoints/model_iter8_last.pth
# INFO:src.io_utils:Saved CSV to outputs/cifar_iter_ema_alpha_0.9_ratio_noise_0.8/iteration_8/metrics/metrics_epoch.csv
# INFO:src.model_utils:Loaded ResNet18 with 10 output classes on device cuda
# INFO:src.train_loop:Iteration 8 done. best_val_acc=0.1810 test_acc=0.7589
# INFO:src.io_utils:Saved npz to outputs/cifar_iter_ema_alpha_0.9_ratio_noise_0.8/iteration_8/preds_npz/preds_iter_8.npz
# Filtering results for iteration 8:
#   Total samples: 45000
#   Kept samples: 8241 (18.31%)
#   Removed samples: 36759 (81.69%)
# Iteration 8 stats overall kept ratio: 0.18313333333333334
#   Samples available for next iteration: 8241
# Summary saved to outputs/cifar_iter_ema_alpha_0.9_ratio_noise_0.8/training_summary.csv
#
# Iteration 8 completed:
#   Validation accuracy: 0.1810
#   Test accuracy: 0.7589
#   Kept ratio: 0.1831
# Starting iteration 9
# Iteration 9 train_loader: 8241 samples
# Reduction from original: 36759 samples (81.69% reduction)
# INFO:src.model_utils:Loaded ResNet18 with 10 output classes on device cuda
# /mnt/c/Users/truon/learning/ptit/research/trung/M_10_01_2025/code/project/src/train_loop.py:34: FutureWarning: `torch.cuda.amp.GradScaler(args...)` is deprecated. Please use `torch.amp.GradScaler('cuda', args...)` instead.
#   scaler = torch.cuda.amp.GradScaler() if use_amp and device.startswith("cuda") else None
# Train:   0%|                                                                                                               | 0/33 [00:00<?, ?it/s]/mnt/c/Users/truon/learning/ptit/research/trung/M_10_01_2025/code/project/src/train_loop.py:42: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast():
# INFO:src.train_loop:Iter 9 Epoch 0: train_acc=0.2451 val_acc=0.1448
# INFO:src.io_utils:Saved checkpoint outputs/cifar_iter_ema_alpha_0.9_ratio_noise_0.8/iteration_9/checkpoints/model_iter9_best.pth
# INFO:src.train_loop:Iter 9 Epoch 1: train_acc=0.4800 val_acc=0.1546
# INFO:src.io_utils:Saved checkpoint outputs/cifar_iter_ema_alpha_0.9_ratio_noise_0.8/iteration_9/checkpoints/model_iter9_best.pth
# INFO:src.train_loop:Iter 9 Epoch 2: train_acc=0.5863 val_acc=0.1638
# INFO:src.io_utils:Saved checkpoint outputs/cifar_iter_ema_alpha_0.9_ratio_noise_0.8/iteration_9/checkpoints/model_iter9_best.pth
# INFO:src.train_loop:Iter 9 Epoch 3: train_acc=0.6598 val_acc=0.1636
# INFO:src.train_loop:Iter 9 Epoch 4: train_acc=0.7012 val_acc=0.1722
# INFO:src.io_utils:Saved checkpoint outputs/cifar_iter_ema_alpha_0.9_ratio_noise_0.8/iteration_9/checkpoints/model_iter9_epoch5.pth
# INFO:src.io_utils:Saved checkpoint outputs/cifar_iter_ema_alpha_0.9_ratio_noise_0.8/iteration_9/checkpoints/model_iter9_best.pth
# INFO:src.train_loop:Iter 9 Epoch 5: train_acc=0.7221 val_acc=0.1718
# INFO:src.train_loop:Iter 9 Epoch 6: train_acc=0.7372 val_acc=0.1750
# INFO:src.io_utils:Saved checkpoint outputs/cifar_iter_ema_alpha_0.9_ratio_noise_0.8/iteration_9/checkpoints/model_iter9_best.pth
# INFO:src.train_loop:Iter 9 Epoch 7: train_acc=0.7568 val_acc=0.1742
# INFO:src.train_loop:Iter 9 Epoch 8: train_acc=0.7778 val_acc=0.1768
# INFO:src.io_utils:Saved checkpoint outputs/cifar_iter_ema_alpha_0.9_ratio_noise_0.8/iteration_9/checkpoints/model_iter9_best.pth
# INFO:src.train_loop:Iter 9 Epoch 9: train_acc=0.7804 val_acc=0.1778
# INFO:src.io_utils:Saved checkpoint outputs/cifar_iter_ema_alpha_0.9_ratio_noise_0.8/iteration_9/checkpoints/model_iter9_epoch10.pth
# INFO:src.io_utils:Saved checkpoint outputs/cifar_iter_ema_alpha_0.9_ratio_noise_0.8/iteration_9/checkpoints/model_iter9_best.pth
# INFO:src.train_loop:Iter 9 Epoch 10: train_acc=0.7846 val_acc=0.1778
# INFO:src.train_loop:Iter 9 Epoch 11: train_acc=0.7987 val_acc=0.1786
# INFO:src.io_utils:Saved checkpoint outputs/cifar_iter_ema_alpha_0.9_ratio_noise_0.8/iteration_9/checkpoints/model_iter9_best.pth
# INFO:src.train_loop:Iter 9 Epoch 12: train_acc=0.8051 val_acc=0.1790
# INFO:src.io_utils:Saved checkpoint outputs/cifar_iter_ema_alpha_0.9_ratio_noise_0.8/iteration_9/checkpoints/model_iter9_best.pth
# INFO:src.train_loop:Iter 9 Epoch 13: train_acc=0.8129 val_acc=0.1788
# INFO:src.train_loop:Iter 9 Epoch 14: train_acc=0.8083 val_acc=0.1796
# INFO:src.io_utils:Saved checkpoint outputs/cifar_iter_ema_alpha_0.9_ratio_noise_0.8/iteration_9/checkpoints/model_iter9_epoch15.pth
# INFO:src.io_utils:Saved checkpoint outputs/cifar_iter_ema_alpha_0.9_ratio_noise_0.8/iteration_9/checkpoints/model_iter9_best.pth
# INFO:src.train_loop:Iter 9 Epoch 15: train_acc=0.8221 val_acc=0.1802
# INFO:src.io_utils:Saved checkpoint outputs/cifar_iter_ema_alpha_0.9_ratio_noise_0.8/iteration_9/checkpoints/model_iter9_best.pth
# INFO:src.train_loop:Iter 9 Epoch 16: train_acc=0.8217 val_acc=0.1786
# INFO:src.train_loop:Iter 9 Epoch 17: train_acc=0.8249 val_acc=0.1786
# INFO:src.train_loop:Iter 9 Epoch 18: train_acc=0.8291 val_acc=0.1818
# INFO:src.io_utils:Saved checkpoint outputs/cifar_iter_ema_alpha_0.9_ratio_noise_0.8/iteration_9/checkpoints/model_iter9_best.pth
# INFO:src.train_loop:Iter 9 Epoch 19: train_acc=0.8274 val_acc=0.1804
# INFO:src.io_utils:Saved checkpoint outputs/cifar_iter_ema_alpha_0.9_ratio_noise_0.8/iteration_9/checkpoints/model_iter9_epoch20.pth
# INFO:src.train_loop:Iter 9 Epoch 20: train_acc=0.8315 val_acc=0.1790
# INFO:src.train_loop:Iter 9 Epoch 21: train_acc=0.8294 val_acc=0.1806
# INFO:src.train_loop:Iter 9 Epoch 22: train_acc=0.8361 val_acc=0.1796
# INFO:src.train_loop:Iter 9 Epoch 23: train_acc=0.8379 val_acc=0.1810
# INFO:src.train_loop:Early stopping in iteration 9 at epoch 23
# INFO:src.io_utils:Saved checkpoint outputs/cifar_iter_ema_alpha_0.9_ratio_noise_0.8/iteration_9/checkpoints/model_iter9_last.pth
# INFO:src.io_utils:Saved CSV to outputs/cifar_iter_ema_alpha_0.9_ratio_noise_0.8/iteration_9/metrics/metrics_epoch.csv
# INFO:src.model_utils:Loaded ResNet18 with 10 output classes on device cuda
# INFO:src.train_loop:Iteration 9 done. best_val_acc=0.1818 test_acc=0.7927
# INFO:src.io_utils:Saved npz to outputs/cifar_iter_ema_alpha_0.9_ratio_noise_0.8/iteration_9/preds_npz/preds_iter_9.npz
# Filtering results for iteration 9:
#   Total samples: 45000
#   Kept samples: 8252 (18.34%)
#   Removed samples: 36748 (81.66%)
# Iteration 9 stats overall kept ratio: 0.18337777777777778
#   Samples available for next iteration: 8252
# Summary saved to outputs/cifar_iter_ema_alpha_0.9_ratio_noise_0.8/training_summary.csv
#
# Iteration 9 completed:
#   Validation accuracy: 0.1818
#   Test accuracy: 0.7927
#   Kept ratio: 0.1834
#
# Training completed. Final summary saved to outputs/cifar_iter_ema_alpha_0.9_ratio_noise_0.8/training_summary.csv
# Best overall validation accuracy: 0.1818

# %%
# 7) Summary
import pandas as pd
summary_df = pd.DataFrame(summary_rows)
summary_df.to_csv(f"{config.exp_dir}/summary_iterations.csv", index=False)
print(summary_df)
# Out:
#    iteration  kept_ratio  val_acc  test_acc  samples_kept  samples_removed  \
# 0          0    0.174022   0.1568    0.5342          7831            37169
# 1          1    0.179467   0.1708    0.7051          8076            36924
# 2          2    0.181778   0.1762    0.7519          8180            36820
# 3          3    0.182089   0.1784    0.7630          8194            36806
# 4          4    0.182533   0.1800    0.7587          8214            36786
# 5          5    0.183378   0.1798    0.7829          8252            36748
# 6          6    0.183733   0.1802    0.7862          8268            36732
# 7          7    0.183222   0.1786    0.7582          8245            36755
# 8          8    0.183133   0.1810    0.7589          8241            36759
# 9          9    0.183378   0.1818    0.7927          8252            36748
#
#    samples_total  training_samples_used
# 0          45000                  45000
# 1          45000                   7831
# 2          45000                   8076
# 3          45000                   8180
# 4          45000                   8194
# 5          45000                   8214
# 6          45000                   8252
# 7          45000                   8268
# 8          45000                   8245
# 9          45000                   8241

# %%
import matplotlib.pyplot as plt

# Vẽ acc theo iteration
plt.figure(figsize=(6,4))
plt.plot(summary_df["iteration"], summary_df["val_acc"], marker="o", label="Val Acc")
plt.plot(summary_df["iteration"], summary_df["test_acc"], marker="s", label="Test Acc")
plt.xlabel("Iteration")
plt.ylabel("Accuracy")
plt.title("Validation & Test Accuracy per Iteration")
plt.legend()
plt.grid(True)
plt.show()

# Vẽ kept ratio
plt.figure(figsize=(6,4))
plt.plot(summary_df["iteration"], summary_df["kept_ratio"], marker="^", color="orange")
plt.xlabel("Iteration")
plt.ylabel("Kept Ratio")
plt.title("Kept Ratio per Iteration")
plt.grid(True)
plt.show()

# %% [markdown]
# # 8) How to resume
